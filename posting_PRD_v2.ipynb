# %% [markdown]
# # Using LLMs to Generate Images and Automate Instagram Accounts Content

# %%
import requests
from openai import OpenAI
import boto3
import urllib.parse
import io
import json
import random
import time






def get_prompt_cheff_jeff():


    url = "https://api.openai.com/v1/chat/completions"

    api_key = ""  # Replace with your actual API key

    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }


    recipe_names = [
    # Italian Cuisine
    # Italian Cuisine
    "Osso Buco", "Carbonara", "Amatriciana Pasta", "Linguine alle Vongole", "Cioppino", "Cacio e Pepe",
    "Bolognese Sauce", "Margherita Pizza", "Caprese Salad", "Tiramisu", "Risotto alla Milanese", "Panna Cotta",
    "Bruschetta al Pomodoro", "Cannoli", "Focaccia Bread", "Panzanella", "Caprese Pizza", "Pasta Primavera",
    "Gelato",

     # Spanish Cuisine
    "Paella", "Pulpo a la Gallega", "Cochinillo Asado", "Fabada Asturiana",
    "Gazpacho", "Churros", "Tortilla Española",  "Ensaladilla Rusa",
    "Sangria",  "Arroz con Leche", "Crema Catalana", "Empanadas Gallegas", "Pinchos",
    "Tarta de Santiago", "Cava Sangria", "Spanish Flan", "Albondigas",

    # French Cuisine
    "Coq au Vin", "Boeuf Bourguignon", "Ratatouille", "Pot au Feu", "Bouillabaisse", "Moules Marinières",
    "Duck à l'Orange", "Croissant", "Crème Brûlée", "Quiche Lorraine",

     # Mexican Cuisine
    "Chiles Rellenos", "Pozole", "Carnitas", "Flautas", "Sopes", "Chilaquiles", "Barbacoa", "Mole Poblano",
    "Tostadas", "Enchiladas Suizas", "Pastel Azteca", "Horchata", "Taco Salad", "Fajita Bowl", "Ceviche",
    "Guacamole", "Mexican Street Corn", "Tres Leches Cake", "Churro Ice Cream Sandwich", "Chiles en Nogada",
    "Mexican Rice", "Menudo", "Pambazos", "Pozole Verde", "Tlacoyos", "Michelada", "Camotes", "Tinga",

    # Greek Cuisine
    "Moussaka", "Souvlaki", "Dolma", "Gemista", "Kleftiko", "Pastitsio",
    "Spanakopita", "Tzatziki", "Galaktoboureko", "Loukoumades",

    # Chinese Cuisine
    "Kung Pao Chicken",  "Szechuan Beef", "Hainanese Chicken Rice", "General Tso's Chicken",
    "Dan Dan Noodles", "Stir-Fried Vegetables", "Hot and Sour Soup", "Spring Rolls", "Dim Sum",

    # Indian Cuisine
    "Chicken Tikka Masala", "Butter Chicken", "Rogan Josh", "Biryani", "Tandoori Chicken", "Vindaloo",
    "Palak Paneer", "Chana Masala", "Samosa", "Masala Dosa",

    # American Cuisine
    "BBQ Ribs", "Fried Chicken", "Buffalo Wings", "Pulled Pork", "Reuben Sandwich", "Philly Cheesesteak",
    "Macaroni and Cheese", "Clam Chowder", "Cornbread", "Key Lime Pie",

    # Lebanese Cuisine
    "Kibbeh", "Lamb Kofta", "Kafta", "Sfeeha", "Fatayer",
    "Hummus", "Falafel", "Tabbouleh", "Shawarma", "Baba Ghanoush"
]

    total_recipes = len(recipe_names)+1
    food_styles_index = random.randint(0, total_recipes)

    food_styles_selected = recipe_names[food_styles_index]

    prompt = f"""

    I want you to write a delcious recipe for {food_styles_selected}.
    Make sure to include spices that would make the dish delicous.
    Make sure the ingrediants you provide are correct and produce a tasty recipe.
    The words surrounded by * indicate you should replace it with your own text.
    Write this delicous food recipe as an instagram caption.
    Make the units of measurement for the ingredients be in American units.
    have your output instagram caption follow the format (you can add more Ingredients and instructions in the lists) following
    this colon:

    " *Recipe Title* \n\n"
        "Ingredients:\n"
        "- \n"
        "- \n"
        "- \n"
        "- \n"

        "Instructions:\n"
        "1. \n"
        "2. \n"
        "3. \n"

        "*One general sentence about the recipe and telling them to enjoy it. Add 25 hashtags*"

    """

    print('***JEFF PROMPT*** : '+str(prompt))

    data = {
        "model": "gpt-3.5-turbo",
        "messages": [{"role": "user",
                    "content": prompt,
                    }],
        "max_tokens": 1000,
        "temperature": 0.5
    }

    response = requests.post(url, headers=headers, data=json.dumps(data))

    if response.status_code == 200:
        response_json = response.json()
        input_caption = response_json["choices"][0]['message']["content"]
        print(' - Insta Real Caption: '+input_caption)
    else:
        print(f"Request failed with status code {response.status_code}: {response.text}")


    input_caption = input_caption
    encoded_caption = urllib.parse.quote(input_caption)




    #     this prompt creates a title for the ai image prompts
    prompt = f"""

    I want you to make a prompt for an AI image generator
    that makes a realistic photo based off of this recipe description {input_caption}.
    Make sure the generated image is realistic.


    """

    data = {
        "model": "gpt-3.5-turbo",
        "messages": [{"role": "user",
                    "content": prompt,
                    }],
        "max_tokens": 1000,
        "temperature": 0.5
    }

    response = requests.post(url, headers=headers, data=json.dumps(data))

    if response.status_code == 200:
        response_json = response.json()
        ouput_caption = response_json["choices"][0]['message']["content"]
        print(' - AI Prompt: '+ouput_caption)
    else:
        print(f"Request failed with status code {response.status_code}: {response.text}")



    return ouput_caption,encoded_caption













def get_prompt_bunns():


    url = "https://api.openai.com/v1/chat/completions"

    api_key = ""  # Replace with your actual API key

    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }



    image_prompts = [
    "A lion leading a motorcycle gang through a blazing savanna",
    "A bear skydiving from a plane engulfed in flames with aviator goggles",
    "A wolf playing poker in a high-stakes game aboard a luxurious yacht",
    "A gorilla skateboarding while chain-smoking and performing tricks",
    "A tiger surfing on a colossal wave amidst a fireworks display",
    "An eagle piloting a fighter jet through exploding meteor showers",
    "A shark hosting a raucous, high-octane casino aboard a pirate ship",
    "A cheetah drifting a high-speed sports car during a thunderstorm",
    "A crocodile bungee jumping from a skyscraper amid an explosive cityscape",
    "A panther DJing at an underground rave with pyrotechnics",
    "A falcon base jumping from an exploding building in a daring escape",
    "A grizzly bear barbecuing with a flamethrower at a wild party",
    "A kangaroo participating in extreme mountain biking through fiery trails",
    "A snake blowing smoke rings while playing poker in a speakeasy",
    "A jaguar leading a daring heist amidst a fireworks-lit city",
    "A bald eagle rocking out on an electric guitar during an explosive concert",
    "A rhinoceros riding a turbo-charged motorcycle through a fireworks show",
    "A polar bear snowboarding down an avalanche of fireworks on a cosmic peak",
    "A fox hacking into a top-secret government database during a fireworks display",
    "A hippopotamus breakdancing amidst an explosive street battle",
    "A falcon skydiving in a firework-laden sky wearing a sleek suit",
    "A gorilla arm wrestling a bodybuilder in a smoky, fiery bar",
    "A cobra hosting an outrageous talk show discussing explosive conspiracies",
    "A leopard performing stunts on a BMX bike with fireworks as the backdrop",
    "A lioness leading an all-female motorcycle gang through a fireworks-filled cityscape",
    "A koala mixing cocktails as a bartender in a flamboyant, explosive club",
    "A tiger playing high-speed chess amidst a whirlwind of fireworks",
    "A bear participating in a demolition derby with explosive cars",
    "A wolf orchestrating a high-stakes robbery amidst fireworks and chaos",
    "A crocodile mastering parkour in an explosive, urban landscape",
    "An eagle leading a squadron of fighter jets through a fireworks-lit sky",
    "A cheetah participating in an explosive parkour competition",
    "A panther playing a saxophone in a jazz band amidst a fireworks extravaganza",
    "A gorilla practicing martial arts in a fiery dojo",
    "A grizzly bear lifting weights in a powerlifting competition with fiery effects",
    "A shark working as a secret agent on a covert mission amidst explosions",
    "A falcon racing in a Formula 1 car through a blaze of fireworks",
    "A jaguar performing as a magician in a grand stage show with explosive effects",
    "A bald eagle leading a team of firefighters through a firework inferno",
    "A rhinoceros skateboarding in a half-pipe amidst exploding fireworks",
    "A polar bear fencing in a championship match amidst dazzling explosions",
    "A fox mastering extreme parkour amidst a spectacular fireworks show",
    "A hippopotamus DJing at a massive music festival with explosive effects",
    "A falcon participating in a high-speed boat race amidst exploding fireworks",
    "A gorilla leading an expedition to climb a mountain in an explosion-filled environment",
    "A cobra practicing acrobatics in a circus with fiery stunts",
    "A leopard creating street art graffiti amidst explosive visuals",
    "A lioness driving a monster truck in an explosive arena show",
    "A koala leading a group of activists in a protest amid dazzling fireworks",
    "A tiger practicing precision archery amidst a fireworks-filled spectacle",
    "A bear participating in extreme motocross racing with explosive effects",
    "A wolf leading a pack of adventurers on an epic quest amidst explosions",
    "A crocodile leading a team of engineers in a construction project with fiery elements",
    "An eagle leading an extreme mountain climbing expedition with fireworks",
    "A cheetah leading an exploration through the Amazon rainforest with explosive visuals",
    "A panther leading a team of astronauts in a space station amidst fiery effects",
    "A gorilla participating in a high-stakes poker tournament amidst explosions",
    "A grizzly bear leading a survival reality TV show with fiery challenges",
    "A shark leading a team in an underwater treasure hunt amidst explosive effects",
    "A falcon participating in an extreme skateboarding competition with fireworks",
    "A jaguar leading a team of artists in a massive mural project amidst explosive creativity",
    "A bald eagle leading a desert expedition with fireworks lighting the way",
    "A rhinoceros participating in extreme skydiving amidst explosive skies",
    "A polar bear leading a thrilling sled dog race amidst explosive snow trails",
    "A fox leading a rebellion against injustice amidst a spectacular fireworks display",
    "A hippopotamus leading a thrilling whitewater rafting race amidst fiery rapids",
    "A falcon leading a team in a world-famous cooking competition with fiery results",
    "A gorilla leading a heart-pounding high-altitude skydiving challenge amidst explosions",
    "A cobra leading a team in an extreme desert survival test with fiery obstacles",
    "A leopard leading a team of explorers in a quest amidst explosive mysteries",
    "A lioness racing in a high-speed motorbike competition amidst fireworks",
    "A koala leading a group of artists in a street art exhibition amidst explosive creations",
    "A tiger leading a team in a worldwide scavenger hunt amidst explosive adventures",
    "A bear leading a team in a thrilling treasure hunt amidst explosive discoveries",
    "A wolf leading a team in a high-speed cross-country race amidst fiery terrains",
    "A crocodile leading a team in a dangerous swamp exploration with explosive challenges",
    "An eagle leading a team in a thrilling canyon jumping challenge amidst fiery landscapes",
    "A cheetah leading a team in a speedboat racing competition amidst explosive waters",
    "A panther leading a team in a thrilling roller coaster design contest with explosive designs"
]





    selected_prompt = random.choice(image_prompts)


#     This prompt generates a prompt to send to AI image generator
    prompt = f"""
    The output text you send me will be used to send to an AI image generator.
    Describe a cartoonish funny animation image thats based on this idea: {selected_prompt}.


    """

    data = {
        "model": "gpt-3.5-turbo",
        "messages": [{"role": "user",
                    "content": prompt,
                    }],
        "max_tokens": 1000,
        "temperature": 1
    }

    response = requests.post(url, headers=headers, data=json.dumps(data))

    if response.status_code == 200:
        response_json = response.json()
        input_caption = response_json["choices"][0]['message']["content"]
        input_caption = input_caption
        input_caption = 'Do not include more than 3 characters: '+input_caption+': Do not include more than 3 characters. '
        print(' - Image Generate Prompt: '+input_caption)
    else:
        print(f"Request failed with status code {response.status_code}: {response.text}")


    hashtags = """#AIart #ArtificialIntelligenceArt #DigitalArtwork #GenerativeArt #AIgenerated #MachineLearningArt #ArtCommunity #ArtisticInspiration #ArtOfTheDay #ArtLovers #CreativeMinds #DigitalIllustration #ArtistsOnInstagram #AnimationArt #AnimationStudio #CharacterDesign #2DAnimation #3DAnimation #ArtistsOfIG #ArtDaily #ArtistsSupportingArtists #ArtWorld #ArtLife #ArtistsCommunity #ArtisticExpression #InstaArtists
    """


    ouput_caption = f"""{selected_prompt}

    {hashtags}
    """

    print('my prompt - '+selected_prompt)


    encoded_caption = urllib.parse.quote(ouput_caption)

    return input_caption,encoded_caption







def get_prompt_dapper():


    url = "https://api.openai.com/v1/chat/completions"

    api_key = ""  # Replace with your actual API key

    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }


#     This prompt generates a prompt to send to AI image generator
    input_caption = """
    Pick between painting or sketch drawing on a sheet of paper.
    Make a drawing that is a fashion concept for mens fashion.
    I want the fashion concepts to be random so they will not easily be regenerated because I am going to ask this many times.
    make the fashion concept realistic, and the clothes can have a variety of colors so long as it looks good.
    have a person wearing the fashion design.
    make the fashion concept contemporary so that someone in todays time would want to wear it.
    make the drawing full body to show fashion of shirts, pants, shoes (optional to add simple necklace or bracelts).
    make sure the fashion concept would be appealing to people that are currently 18-35 years old.
    use different clothing colors and different fashion design ideas to ensure randomness and that there is a low probablity a concept will be repeated.
    still make sure that the fashion concept is attractive.
    you can pick from spring, summer, fall, and winter fashion concept ideas.
    i want the concept to be a cool new unique fashion design so that everytime you get this prompt you make something new.
    Use this information to describe exactly what the person is wearing. Describe every detail of the outfit.



    """






#     this prompt creates a title for the ai image prompts
    prompt = """

    Create a cool title that will be used as an instagram caption for a mens fashion concept image.
    Come up with a random unqiue caption about mens fashion and anything related so that the caption would not be easily repeated.
    Make sure the output is just a one sentence title. Also add exactly 25 hashtags at the end of the caption that are popular for mens fashion, fashion design, and general popluar fashion hashtags.


    """

    data = {
        "model": "gpt-3.5-turbo",
        "messages": [{"role": "user",
                    "content": prompt,
                    }],
        "max_tokens": 1000,
        "temperature": 0.5
    }

    response = requests.post(url, headers=headers, data=json.dumps(data))

    if response.status_code == 200:
        response_json = response.json()
        ouput_caption = response_json["choices"][0]['message']["content"]
        print(' - Insta Real Caption: '+ouput_caption)
    else:
        print(f"Request failed with status code {response.status_code}: {response.text}")


    encoded_caption = urllib.parse.quote(ouput_caption)

    return input_caption,encoded_caption










def get_prompt_sports_spectra():
    sports_data = {'football': [
        {"team": "Arizona Cardinals", "colors": ["Black", "Red", "White"]},
        {"team": "Atlanta Falcons", "colors": ["Black", "Red", "Silver", "White"]},
        {"team": "Baltimore Ravens", "colors": ["Black", "Purple", "Gold"]},
        {"team": "Buffalo Bills", "colors": ["Blue", "Red", "White"]},
        {"team": "Carolina Panthers", "colors": ["Blue", "Black", "Silver", "White"]},
        {"team": "Chicago Bears", "colors": ["Blue", "Orange", "White"]},
        {"team": "Cincinnati Bengals", "colors": ["Black", "Orange", "White"]},
        {"team": "Dallas Cowboys", "colors": ["Blue", "Silver", "White"]},
        {"team": "Denver Broncos", "colors": ["Blue", "Orange", "White"]},
        {"team": "Detroit Lions", "colors": ["Blue", "Silver", "White"]},
        {"team": "Houston Texans", "colors": ["Blue", "Red", "White"]},
        {"team": "Indianapolis Colts", "colors": ["Blue", "White"]},
        {"team": "Jacksonville Jaguars", "colors": ["Black", "Teal", "Gold"]},
        {"team": "Kansas City Chiefs", "colors": ["Red", "Gold", "White"]},
        {"team": "Las Vegas Raiders", "colors": ["Black", "Silver", "White"]},
        {"team": "Los Angeles Chargers", "colors": ["Blue", "Gold", "White"]},
        {"team": "Los Angeles Rams", "colors": ["Blue", "Gold", "White"]},
        {"team": "Miami Dolphins", "colors": ["Aqua", "Orange", "White"]},
        {"team": "Minnesota Vikings", "colors": ["Purple", "Gold", "White"]},
        {"team": "New England Patriots", "colors": ["Blue", "Red", "Silver", "White"]},
        {"team": "New Orleans Saints", "colors": ["Black", "Gold", "White"]},
        {"team": "New York Giants", "colors": ["Blue", "Red", "White"]},
        {"team": "New York Jets", "colors": ["Green", "White"]},
        {"team": "Philadelphia Eagles", "colors": ["Green", "Silver", "White"]},
        {"team": "Pittsburgh Steelers", "colors": ["Black", "Gold", "White"]},
        {"team": "San Francisco 49ers", "colors": ["Red", "Gold", "White"]},
        {"team": "Seattle Seahawks", "colors": ["Blue", "Green", "Grey", "White"]},
        {"team": "Tampa Bay Buccaneers", "colors": ["Red", "Pewter", "White"]},
        {"team": "Tennessee Titans", "colors": ["Navy", "Columbia Blue", "White"]},
        {"team": "Alabama Crimson Tide", "colors": ["Crimson", "White"]},
        {"team": "Arkansas Razorbacks", "colors": ["Cardinal", "White"]},
        {"team": "Auburn Tigers", "colors": ["Navy", "Burnt Orange", "White"]},
        {"team": "Florida Gators", "colors": ["Blue", "Orange", "White"]},
        {"team": "Georgia Bulldogs", "colors": ["Red", "Black", "Silver"]},
        {"team": "Kentucky Wildcats", "colors": ["Blue", "White"]},
        {"team": "LSU Tigers", "colors": ["Purple", "Gold", "White"]},
        {"team": "Mississippi State Bulldogs", "colors": ["Maroon", "White"]},
        {"team": "Missouri Tigers", "colors": ["Black", "Gold"]},
        {"team": "Ole Miss Rebels", "colors": ["Navy", "Red", "Gray", "White"]},
        {"team": "Tennessee Volunteers", "colors": ["Orange", "White"]},
        {"team": "Texas A&M Aggies", "colors": ["Maroon", "White", "Gray"]}
    ],

                    'basketball': [
        {"team": "Atlanta Hawks", "colors": ["Red", "Black", "White", "Gold"]},
        {"team": "Boston Celtics", "colors": ["Green", "White", "Gold"]},
        {"team": "Brooklyn Nets", "colors": ["Black", "White", "Gray"]},
        {"team": "Charlotte Hornets", "colors": ["Teal", "Purple", "White"]},
        {"team": "Chicago Bulls", "colors": ["Red", "Black", "White"]},
        {"team": "Cleveland Cavaliers", "colors": ["Wine", "Gold", "Black", "White"]},
        {"team": "Dallas Mavericks", "colors": ["Navy", "Royal Blue", "Silver", "White"]},
        {"team": "Denver Nuggets", "colors": ["Navy", "Gold", "Sky Blue", "White"]},
        {"team": "Golden State Warriors", "colors": ["Royal Blue", "Gold", "White"]},
        {"team": "Houston Rockets", "colors": ["Red", "Black", "White", "Silver"]},
        {"team": "Indiana Pacers", "colors": ["Navy", "Gold", "White", "Silver"]},
        {"team": "LA Clippers", "colors": ["Red", "Blue", "White"]},
        {"team": "Los Angeles Lakers", "colors": ["Purple", "Gold", "White"]},
        {"team": "Memphis Grizzlies", "colors": ["Navy", "Beale Street Blue", "Smoke Blue", "White"]},
        {"team": "Miami Heat", "colors": ["Red", "Black", "White", "Gold"]},
        {"team": "Milwaukee Bucks", "colors": ["Green", "Cream", "Black"]},
        {"team": "Minnesota Timberwolves", "colors": ["Midnight Blue", "Aurora Green", "Moonlight Grey", "White"]},
        {"team": "New Orleans Pelicans", "colors": ["Navy", "Red", "Gold", "White"]},
        {"team": "New York Knicks", "colors": ["Blue", "Orange", "White"]},
        {"team": "Oklahoma City Thunder", "colors": ["Navy", "Sunset", "Blue", "Yellow", "White"]},
        {"team": "Orlando Magic", "colors": ["Black", "Blue", "White", "Silver"]},
        {"team": "Philadelphia 76ers", "colors": ["Blue", "Red", "White"]},
        {"team": "Phoenix Suns", "colors": ["Purple", "Orange", "Black", "White"]},
        {"team": "Portland Trail Blazers", "colors": ["Red", "Black", "White"]},
        {"team": "Sacramento Kings", "colors": ["Purple", "Black", "Silver", "White"]},
        {"team": "San Antonio Spurs", "colors": ["Black", "White", "Silver", "Gray"]},
        {"team": "Toronto Raptors", "colors": ["Red", "Black", "Gold"]},
        {"team": "Utah Jazz", "colors": ["Navy", "Gold", "Green", "White"]},
        {"team": "Washington Wizards", "colors": ["Red", "White", "Navy", "Silver"]},
        {"team": "Alabama Crimson Tide", "colors": ["Crimson", "White"]},
        {"team": "Arkansas Razorbacks", "colors": ["Cardinal", "White"]},
        {"team": "Auburn Tigers", "colors": ["Navy", "Burnt Orange", "White"]},
        {"team": "Florida Gators", "colors": ["Blue", "Orange", "White"]},
        {"team": "Georgia Bulldogs", "colors": ["Red", "Black", "Silver"]},
        {"team": "Kentucky Wildcats", "colors": ["Blue", "White"]},
        {"team": "LSU Tigers", "colors": ["Purple", "Gold", "White"]},
        {"team": "Mississippi State Bulldogs", "colors": ["Maroon", "White"]},
        {"team": "Ole Miss Rebels", "colors": ["Navy", "Red", "Gray", "White"]},
        {"team": "Tennessee Volunteers", "colors": ["Orange", "White"]},
        {"team": "Texas A&M Aggies", "colors": ["Maroon", "White", "Gray"]}
    ]
    }




    random_sport = random.choice(list(sports_data.keys()))
    random_team = random.choice(sports_data[random_sport])

#     adding two mascots so 50% chance mascot 50% change logo/jersey design
    image_concept_all = {   'mascot_one':{'football':f"""3d animation design of your interpretation of an intense {random_team['team']} mascot (not a real person. make sure it is a mascot.) in the teams jersey and jersey colors and make the mascot muscular and athletic and scoring a touchdown on football field. Make sure to use the teams colors. Put spot lights on the football field.""",
        'basketball':f"""3d animation design of your interpretation of an intense {random_team['team']} mascot (not a real person. make sure it is a mascot.) in the teams jersey and jersey colors and make the mascot muscular and athletic and dunking a basketball on a basketball court. Make sure to use the teams colors. Put spot lights on the basketball court."""
        },
#                           'mascot_two':{'football':'3d animation design of your interpretation of the mascot in the teams jersey and jersey colors and make the mascot muscular and athletic and scoring a touchdown on football field. Make sure to use the teams colors. Put spot lights on the football field and place the football field in an amazing place.',
#         'basketball':'3d animation design of your interpretation of the mascot in the teams jersey and jersey colors and make the mascot muscular and athletic and dunking a basketball on a basketball court. Make sure to use the teams colors. Put spot lights on the basketball court and place the basketball court in an amazing place.'
#         },
#                          'logo':'3d animation new logo design for this sports team. Make sure to use the teams colors. Only use graphics of images and no text.',
#                           'jersey':f"""a new jersey design for the {random_team['team']} {random_sport} team. Make the jersey an innovative design. Make sure to use the teams colors. Make a cool background with spot lights. Put the jersey on one individual 3d animated person in {random_sport} gear."""
    }



    random_image_concept = random.choice(list(image_concept_all.keys()))


    if random_image_concept=='mascot_one' or  random_image_concept=='mascot_two':
        image_concept_prompt = image_concept_all[random_image_concept][random_sport]
        prompt_additional_reference = 'their mascot'
    else:
        image_concept_prompt = image_concept_all[random_image_concept]
        prompt_additional_reference = " a new "+random_image_concept+" design"



    ai_image_prompt_input = f"""For the {random_sport} team the {random_team['team']} with team colors {', '.join(random_team['colors'])}.
    Make an image for a {image_concept_prompt}
    """

    ai_image_prompt_input = f"""
    Your output will be instructing an AI image generator. I want you to describe in detail
    this idea: '{ai_image_prompt_input}'.
    If you tell the AI image generator to include text, make sure to reiterate what the text is and ensure that
    the AI image generator will include the correctly spelled text. Do not use generic text like "football" or "basketball".
    Add as many details you want to describe the appearence of the mascot.
    """


    url = "https://api.openai.com/v1/chat/completions"
    api_key = ""  # Replace with your actual API key

    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }





    data = {
        "model": "gpt-3.5-turbo",
        "messages": [{"role": "user",
                    "content": ai_image_prompt_input,
                    }],
        "max_tokens": 1000,
        "temperature": 1
    }

    response = requests.post(url, headers=headers, data=json.dumps(data))

    if response.status_code == 200:
        response_json = response.json()
        final_image_prompt = response_json["choices"][0]['message']["content"]
        print(' - AI image prompt: '+final_image_prompt)
    else:
        print(f"Request failed with status code {response.status_code}: {response.text}")






    #     this prompt creates a title for the ai image prompts
    prompt = f"""

    Create a one sentence instagram caption for the {random_team['team']} {random_sport} team that references {prompt_additional_reference} and {random_team['team']}.
    Also add 25 hashtags at the end of the caption that are popular for this sport prompt.


    """

    data = {
        "model": "gpt-3.5-turbo",
        "messages": [{"role": "user",
                    "content": prompt,
                    }],
        "max_tokens": 1000,
        "temperature": 0.5
    }

    response = requests.post(url, headers=headers, data=json.dumps(data))

    if response.status_code == 200:
        response_json = response.json()
        ouput_caption = response_json["choices"][0]['message']["content"]
        print(' - Insta Real Caption: '+ouput_caption)
    else:
        print(f"Request failed with status code {response.status_code}: {response.text}")


    encoded_caption = urllib.parse.quote(ouput_caption)


    return final_image_prompt,encoded_caption




















def get_ai_image(caption):
    # real api key
    api_key = ""  # Replace with your actual API key
    client = OpenAI(api_key=api_key)

    img_data = client.images.generate(
    model="dall-e-3",
    prompt= caption,
    size="1024x1024",
    quality="standard",
    n=1,
    )

    image_url = img_data.data[0].url

    response = requests.get(image_url)

    return response



def store_image_in_s3_bucket(img_stored_name,response):

    ACCESS_ID = ''
    ACCESS_KEY = ''
    s3 = boto3.client('s3', aws_access_key_id=ACCESS_ID,
            aws_secret_access_key= ACCESS_KEY)

    img_bytes = response.content

    # uploading to s3
    s3.upload_fileobj(io.BytesIO(img_bytes),'',img_stored_name+'.jpeg',ExtraArgs={'ACL':'public-read'})

    #  getting image s3 bucket url
    img_link_s3 = ''+img_stored_name+''

    return img_link_s3





def post_single_image(image_url,caption,insta_account_id,token):
    img_resp = requests.post(f"https://graph.facebook.com/v18.0/{insta_account_id}/media?image_url={image_url}&caption={caption}&access_token={token}")
    img_container = img_resp.json()
    print(img_container)
    curr_img_id = img_container['id']

    img_post_cont = requests.post(f"https://graph.facebook.com/v18.0/{insta_account_id}/media_publish?creation_id={curr_img_id}&access_token={token}")

    return img_post_cont



def clear_s3_bucket():
    ACCESS_ID = ''
    ACCESS_KEY = ''
    s3 = boto3.client('s3', aws_access_key_id=ACCESS_ID,
            aws_secret_access_key= ACCESS_KEY)

    # First we list all files in folder
    response = s3.list_objects_v2(Bucket='')
    files_in_folder = response["Contents"]


    files_to_delete = []
    # We will create Key array to pass to delete_objects function
    for f in files_in_folder:
        files_to_delete.append({"Key": f["Key"]})


    # This will delete all files in a folder
    response = s3.delete_objects(
        Bucket='bunns', Delete={"Objects": files_to_delete}
    )













# RUNNING CHEFF JEFF
def run_jeff():
    print('********JEFF********')
    client_id = ''
    secret = ''
    page_id = ''
    insta_account_id =  ""
    long_token = dict()
    long_token['access_token'] = ''


    input_caption,encoded_caption = get_prompt_cheff_jeff()
    response = get_ai_image("Make a realistic photo image based on this recipes title and description: "+input_caption)

    unique_id = str(int(time.time()))
    img_link_s3 = store_image_in_s3_bucket('cheff_jeff'+unique_id,response)

    encoded_caption = encoded_caption.replace("%22", "")
    post_single_image(img_link_s3,
                  encoded_caption,
                  insta_account_id,
                  long_token['access_token']
                 )
















# RUNNING BUNNS
def run_bunns():
    print('********BUNNS********')
    client_id = ''
    secret = ''
    page_id = ''
    insta_account_id =  ""
    long_token = dict()
    long_token['access_token'] = ''


    input_caption,encoded_caption = get_prompt_bunns()
    response = get_ai_image(input_caption)

    unique_id = str(int(time.time()))
    img_link_s3 = store_image_in_s3_bucket('p_bunns'+unique_id,response)

    encoded_caption = encoded_caption.replace("%22", "")
    post_single_image(img_link_s3,
                  encoded_caption,
                  insta_account_id,
                  long_token['access_token']
                 )






# RUNNING DAPPER
def run_dapp():
    print('********DAPP********')
    client_id = ''
    secret = ''
    page_id = ''
    insta_account_id =  ""

    long_token = dict()
    long_token['access_token'] = ''


    input_caption,encoded_caption = get_prompt_dapper()
    response = get_ai_image(input_caption)

    unique_id = str(int(time.time()))
    img_link_s3 = store_image_in_s3_bucket('dapper'+unique_id,response)

    encoded_caption = encoded_caption.replace("%22", "")
    post_single_image(img_link_s3,
                  encoded_caption,
                  insta_account_id,
                  long_token['access_token']
                 )







# RUNNING DAPPER
def run_spectra():
    print('********spectra********')
    client_id = ''
    secret = ''
    page_id = ''
    insta_account_id =  ""


    # only need to get long lived token when current one at bottom expires
    # long_token = get_long_lived_token(token,client_id,secret)

    long_token = dict()
    long_token['access_token'] = ''

    input_caption,encoded_caption = get_prompt_sports_spectra()
    response = get_ai_image(input_caption)


    unique_id = str(int(time.time()))
    img_link_s3 = store_image_in_s3_bucket('spectra'+unique_id,response)

    encoded_caption = encoded_caption.replace("%22", "")
    post_single_image(img_link_s3,
                  encoded_caption,
                  insta_account_id,
                  long_token['access_token']
                 )




run_jeff()
time.sleep(60)
run_bunns()
time.sleep(60)
run_dapp()
# time.sleep(60)
# run_spectra()

clear_s3_bucket()
# Out:
# ********BUNNS********
#  - Image Generate Prompt: Do not include more than 3 characters: In this hilarious cartoonish animation image, we see a group of animal adventurers participating in an extreme desert survival test, led by none other than a charismatic cobra named Charlie. The desert setting is filled with fiery obstacles that add a thrilling element to the challenge.
#
# Charlie, the cobra, stands tall with a confident and determined expression, wearing a desert-themed explorer outfit complete with a hat and adventure gear. His team consists of various comical and diverse animal characters, each with their own unique skill sets.
#
# On Charlie's left, we have a plucky meerkat named Marty, known for his keen sense of observation. Marty is seen keeping an eye out for any hidden dangers, his small stature somehow making him even more adorable.
#
# ...
